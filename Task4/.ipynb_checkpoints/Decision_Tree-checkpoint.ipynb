# %% [markdown]
# # Task 4 - Decison Tree Classifier on iris Data

# %% [markdown]
# <b> In this task , bascially we have to visualize Decision Tree graphically.The purpose of this task is to feed any new data to this classifier, it would be able to predict the right class accordingly. </b>

# %% [markdown]
# <H3> This Notebook covers: </H3>
# <ul>
#    <li> How to Fit a Decision Tree Model using Scikit-Learn </li>
# <li> How to Visualize Decision Trees using Matplotlib </li>
# <li> How to Visualize Decision Trees using Graphviz </li>
# </ul>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn import tree

# %%
iris_df = pd.read_csv('../Datasets/Iris.csv')

# %%
iris_df
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %%
pd.get_dummies(iris_df['Species'])
# Out:
#      Iris-setosa  Iris-versicolor  Iris-virginica
# 0              1                0               0
# 1              1                0               0
# 2              1                0               0
# 3              1                0               0
# 4              1                0               0
# ..           ...              ...             ...
# 145            0                0               1
# 146            0                0               1
# 147            0                0               1
# 148            0                0               1
# 149            0                0               1
#
# [150 rows x 3 columns]

# %% [markdown]
# ### Converting target variable to Numeric

# %%
label = LabelEncoder()

# %%
iris_df['Species']=label.fit_transform(iris_df['Species'])

# %%
iris_df
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  Species
# 0      1            5.1           3.5            1.4           0.2        0
# 1      2            4.9           3.0            1.4           0.2        0
# 2      3            4.7           3.2            1.3           0.2        0
# 3      4            4.6           3.1            1.5           0.2        0
# 4      5            5.0           3.6            1.4           0.2        0
# ..   ...            ...           ...            ...           ...      ...
# 145  146            6.7           3.0            5.2           2.3        2
# 146  147            6.3           2.5            5.0           1.9        2
# 147  148            6.5           3.0            5.2           2.0        2
# 148  149            6.2           3.4            5.4           2.3        2
# 149  150            5.9           3.0            5.1           1.8        2
#
# [150 rows x 6 columns]

# %% [markdown]
# ## Dependent and Independent Features

# %%
X = iris_df.iloc[:,[1,2,3,4]].values
y = iris_df.iloc[:,-1].values

# %% [markdown]
# ## Splitting into Training Set and Test Set

# %%
X_train, X_test, y_train, y_test = train_test_split(
...     X, y, test_size=0.25, random_state=42)

# %%
y_train
# Out:
# array([0, 0, 2, 1, 1, 0, 0, 1, 2, 2, 1, 2, 1, 2, 1, 0, 2, 1, 0, 0, 0, 1,
#        2, 0, 0, 0, 1, 0, 1, 2, 0, 1, 2, 0, 2, 2, 1, 1, 2, 1, 0, 1, 2, 0,
#        0, 1, 1, 0, 2, 0, 0, 1, 1, 2, 1, 2, 2, 1, 0, 0, 2, 2, 0, 0, 0, 1,
#        2, 0, 2, 2, 0, 1, 1, 2, 1, 2, 0, 2, 1, 2, 1, 1, 1, 0, 1, 1, 0, 1,
#        2, 2, 0, 1, 2, 2, 0, 2, 0, 1, 2, 2, 1, 2, 1, 1, 2, 2, 0, 1, 2, 0,
#        1, 2])

# %% [markdown]
# ## Training on Model

# %%
#Make an instance of the Model
clf = DecisionTreeClassifier(max_depth = 2, 
                             random_state = 0)

# Step 3: Train the model on the data
clf.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(max_depth=2, random_state=0)

# %%
# Predict labels of unseen (test) data
clf.predict(X_test)
# Out:
# array([1, 0, 2, 1, 2, 0, 1, 2, 1, 1, 2, 0, 0, 0, 0, 1, 2, 1, 1, 2, 0, 2,
#        0, 2, 2, 2, 2, 2, 0, 0, 0, 0, 1, 0, 0, 2, 1, 0])

# %% [markdown]
# ## plots a decision tree using scikit-learn

# %%
tree.plot_tree(clf)
# Out:
# [Text(133.92000000000002, 181.2, 'X[3] <= 0.8\ngini = 0.666\nsamples = 112\nvalue = [35, 39, 38]'),
#  Text(66.96000000000001, 108.72, 'gini = 0.0\nsamples = 35\nvalue = [35, 0, 0]'),
#  Text(200.88000000000002, 108.72, 'X[2] <= 4.75\ngini = 0.5\nsamples = 77\nvalue = [0, 39, 38]'),
#  Text(133.92000000000002, 36.23999999999998, 'gini = 0.056\nsamples = 35\nvalue = [0, 34, 1]'),
#  Text(267.84000000000003, 36.23999999999998, 'gini = 0.21\nsamples = 42\nvalue = [0, 5, 37]')]

# %%
fn=['sepal length (cm)','sepal width (cm)','petal length (cm)','petal width (cm)']
cn=['setosa', 'versicolor', 'virginica']
fig, axes = plt.subplots(nrows = 1,ncols = 1,figsize = (4,4), dpi=300)
tree.plot_tree(clf,
               feature_names = fn, 
               class_names=cn,
               filled = True)
# Out:
# [Text(372.0, 755.0, 'petal width (cm) <= 0.8\ngini = 0.666\nsamples = 112\nvalue = [35, 39, 38]\nclass = versicolor'),
#  Text(186.0, 453.0, 'gini = 0.0\nsamples = 35\nvalue = [35, 0, 0]\nclass = setosa'),
#  Text(558.0, 453.0, 'petal length (cm) <= 4.75\ngini = 0.5\nsamples = 77\nvalue = [0, 39, 38]\nclass = versicolor'),
#  Text(372.0, 151.0, 'gini = 0.056\nsamples = 35\nvalue = [0, 34, 1]\nclass = versicolor'),
#  Text(744.0, 151.0, 'gini = 0.21\nsamples = 42\nvalue = [0, 5, 37]\nclass = virginica')]

# %% [markdown]
# ## How to Visualize Decision Trees using Graphviz

# %% [markdown]
# generates the dot file and exports it as a file named tree.dot

# %%
tree.export_graphviz(clf,
                     out_file="tree.dot",
                     feature_names = fn, 
                     class_names=cn,
                     filled = True)

# %% [markdown]
# convert the dot file into a png file.

# %%
! dot -Tpng tree.dot -o output/tree.png
